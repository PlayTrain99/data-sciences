# %% [markdown]
# <a href="https://colab.research.google.com/github/PlayTrain99/data-sciences/blob/main/WizualizacjeDanych/WizualizacjeDanych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fig = plt.figure()
fig.show()

# %%
plt.plot([0,1], [0, 3])

# %%
plt.plot([0,1,2], [0, 3,4], label='line', color="green")
plt.legend()
plt.xlabel('oś X')
plt.ylabel('oś Y')
plt.title("Wykres cos")
# Out:
# Text(0.5, 1.0, 'Wykres cos')

# %%
x = np.arange(-3, 3, 0.1, dtype=float)
x_sin = np.sin(x)
plt.plot(x, x_sin)

# %% [markdown]
# # Zadanie z obrzami

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("office.jpg")
img
# Out:
# array([[[117,  98,  56],
#         [117,  98,  56],
#         [116,  97,  55],
#         ...,
#         [ 98,  82,  48],
#         [ 98,  82,  48],
#         [ 95,  79,  45]],
#
#        [[118,  99,  57],
#         [120, 101,  59],
#         [121, 102,  60],
#         ...,
#         [101,  85,  51],
#         [101,  85,  51],
#         [ 97,  81,  47]],
#
#        [[116,  97,  55],
#         [118,  99,  57],
#         [120, 101,  59],
#         ...,
#         [108,  92,  58],
#         [104,  88,  54],
#         [100,  84,  50]],
#
#        ...,
#
#        [[ 84,  65,  22],
#         [ 86,  67,  24],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  35,   1],
#         [ 58,  35,   1],
#         [ 58,  35,   1]],
#
#        [[ 86,  67,  24],
#         [ 87,  68,  25],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  33,   2],
#         [ 58,  33,   2],
#         [ 57,  32,   1]],
#
#        [[ 88,  69,  26],
#         [ 90,  71,  28],
#         [ 91,  72,  30],
# ...

# %%
img.shape
# Out:
# (426, 640, 3)

# %%
plt.imshow(img)
_ = plt.axis('off')

# %%
fig = plt.figure(figsize=(12, 10))
plt.subplot(221)
plt.imshow(mpimg.imread("office.jpg"))
plt.subplot(222)
plt.imshow(mpimg.imread("business.jpg"))
plt.imshow(mpimg.imread("office.jpg"))
plt.subplot(223)
plt.imshow(mpimg.imread("children.jpg"))

# %%
fig = plt.figure(figsize=(12, 10))

for idx, img in enumerate(["office.jpg", "business.jpg", "children.jpg"]):
  plt.subplot(140 + idx + 1)
  plt.imshow(mpimg.imread(img))

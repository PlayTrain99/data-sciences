# %% [markdown]
# <a href="https://colab.research.google.com/github/PlayTrain99/data-sciences/blob/main/Pandas/Pandas_first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# # Podstawowa struktura pandas itp

# %%
s = pd.Series(data=[3,2,4,6])
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    6
# dtype: int64

# %%
s = pd.Series(data=[3,2,4,6], index = ["a","b","c","d"], name = "sampel")
s
# Out:
# a    3
# b    2
# c    4
# d    6
# Name: sampel, dtype: int64

# %%
s = pd.Series(data=[3.0,2,4,6], index = ["a","b","c","d"], name = "sampel")
s
# Out:
# a    3.0
# b    2.0
# c    4.0
# d    6.0
# Name: sampel, dtype: float64

# %%
import numpy as np

s = pd.Series(data=[3.0, np.nan , 4, 6], index = ["a","b","c","d"], name = "sampel")
s
# Out:
# a    3.0
# b    NaN
# c    4.0
# d    6.0
# Name: sampel, dtype: float64

# %%
s = pd.Series(data = np.arange(10, 20), index=pd.date_range(start="20200101", periods=10))
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int64

# %%
list(s.index)
# Out:
# [Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-01-02 00:00:00'),
#  Timestamp('2020-01-03 00:00:00'),
#  Timestamp('2020-01-04 00:00:00'),
#  Timestamp('2020-01-05 00:00:00'),
#  Timestamp('2020-01-06 00:00:00'),
#  Timestamp('2020-01-07 00:00:00'),
#  Timestamp('2020-01-08 00:00:00'),
#  Timestamp('2020-01-09 00:00:00'),
#  Timestamp('2020-01-10 00:00:00')]

# %%
s = pd.Series(data=["python", "sql", "java"], name="language")
s
# Out:
# 0    python
# 1       sql
# 2      java
# Name: language, dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['python', 'sql', 'java'], dtype=object)

# %%
s.shape
# Out:
# (3,)

# %%
price = pd.Series(data={"apple":200, "CDproejct":100, "Amzon":1700}, name="Company value")
price
# Out:
# apple         200
# CDproejct     100
# Amzon        1700
# Name: Company value, dtype: int64

# %%
price["apple"]
# Out:
# 200

# %%
price.count()
# Out:
# 3

# %%
price.value_counts()
# Out:
# Company value
# 200     1
# 100     1
# 1700    1
# Name: count, dtype: int64

# %%
price.sum()
# Out:
# 2000

# %%
price.describe()
# Out:
# count       3.000000
# mean      666.666667
# std       896.288644
# min       100.000000
# 25%       150.000000
# 50%       200.000000
# 75%       950.000000
# max      1700.000000
# Name: Company value, dtype: float64

# %%
price.nlargest(2)
# Out:
# Amzon    1700
# apple     200
# Name: Company value, dtype: int64

# %%
prrices_pl = price.apply(lambda x: x * 3.8)
prrices_pl
# Out:
# apple         760.0
# CDproejct     380.0
# Amzon        6460.0
# Name: Company value, dtype: float64

# %%
price
# Out:
# apple         200
# CDproejct     100
# Amzon        1700
# Name: Company value, dtype: int64

# %% [markdown]
# # Striktura danych: pd.DataFrame

# %%
df = pd.DataFrame(data=[12, 12 , 32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
df = pd.DataFrame(data=[12, 12 , 32], index=["first", "second", 'third'], columns=["col_1"])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
df = pd.DataFrame(data={"WIG20":["PKN Orlen", "PKO BP"],
                        "mWIG40":["Amica", "Playway"]})
df
# Out:
#        WIG20   mWIG40
# 0  PKN Orlen    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data=[[12, 12 , 32], [32, 23 , 11]], index=["first", "second"], columns=["col_1", "col_2", "col_3"])
df
# Out:
#         col_1  col_2  col_3
# first      12     12     32
# second     32     23     11

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
df.describe()
# Out:
#            col_1      col_2      col_3
# count   2.000000   2.000000   2.000000
# mean   22.000000  17.500000  21.500000
# std    14.142136   7.778175  14.849242
# min    12.000000  12.000000  11.000000
# 25%    17.000000  14.750000  16.250000
# 50%    22.000000  17.500000  21.500000
# 75%    27.000000  20.250000  26.750000
# max    32.000000  23.000000  32.000000

# %%
df.describe().T
# Out:
#        count  mean        std   min    25%   50%    75%   max
# col_1    2.0  22.0  14.142136  12.0  17.00  22.0  27.00  32.0
# col_2    2.0  17.5   7.778175  12.0  14.75  17.5  20.25  23.0
# col_3    2.0  21.5  14.849242  11.0  16.25  21.5  26.75  32.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['std'].plot(kind='hist', bins=20, title='std')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['min'].plot(kind='hist', bins=20, title='min')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['25%'].plot(kind='hist', bins=20, title='25%')
# ...

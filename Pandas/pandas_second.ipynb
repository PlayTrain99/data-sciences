# %% [markdown]
# <a href="https://colab.research.google.com/github/PlayTrain99/data-sciences/blob/main/Pandas/pandas_second.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=[[12, 12 , 32], [32, 23 , 11]], index=["first", "second"], columns=["col_1", "col_2", "col_3"])
df
# Out:
#         col_1  col_2  col_3
# first      12     12     32
# second     32     23     11

# %%
df[["col_1"]]
# Out:
#         col_1
# first      12
# second     32

# %%
type(df[["col_1"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ["a" , "b", "c"]
df
# Out:
#          a   b   c
# first   12  12  32
# second  32  23  11

# %%
df["d"] = df.a + df.c
df
# Out:
#          a   b   c   d
# first   12  12  32  44
# second  32  23  11  43

# %%
df = pd.DataFrame(data=[[12, 12 , 32], [32, 23 , 11]], index=["first", "second"], columns=["col_1", "col_2", "col_3"])
df
# Out:
#         col_1  col_2  col_3
# first      12     12     32
# second     32     23     11

# %%
df.iloc[0]
# Out:
# col_1    12
# col_2    12
# col_3    32
# Name: first, dtype: int64

# %%
df.loc[:, "col_2"]
# Out:
# first     12
# second    23
# Name: col_2, dtype: int64

# %%
df.col_1.hist(bins=3)
# Out:
# <Axes: >

# %%
df.col_3.plot()
# Out:
# <Axes: >
